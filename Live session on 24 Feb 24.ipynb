# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import  StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import  train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
live = pd.read_csv('titanic_train.csv')

# %%
### It is a classcification  model
live
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
live=live.drop(['PassengerId','Unnamed: 0'], axis=1)

# %%
live
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare    Cabin Embarked
# ...

# %%
live.shape
# Out:
# (891, 12)

# %%
live.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
live.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
live['Age']=live['Age'].fillna(live['Age'].mode()[0])
live['Cabin']=live['Cabin'].fillna(live['Cabin'].mode()[0])
live['Embarked']=live['Embarked'].fillna(live['Embarked'].mode()[0])

# %%
live.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
live.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
plt.figure(figsize=(20,25),facecolor='red')
plotnum=1
for column in live:
    if plotnum<=8:
        ax= plt.subplot(2,4,plotnum)
        sns.distplot(live[column])
        plt.xlabel(column, fontsize=20)
        
    plotnum+=1
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 6
#       4 if plotnum<=8:
#       5     ax= plt.subplot(2,4,plotnum)
# ----> 6     sns.distplot(live[column])
#       7     plt.xlabel(column, fontsize=20)
#       9 plotnum+=1
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:2458, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2455     a = x
#    2457 # Make a a 1-d float array
# -> 2458 a = np.asarray(a, float)
#    2459 if a.ndim > 1:
#    2460     a = a.squeeze()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:893, in Series.__array__(self, dtype)
#     846 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#     847     """
#     848     Return the values as a NumPy array.
#     849
#    (...)
# ...

# %%
sns.countplot(x='Survived', data=live)
plt.show()

# %%
live.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   28.566970    0.523008
# std     257.353842    0.486592    0.836071   13.199572    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   24.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
plt.figure(figsize=(14,20))
plotnum = 1
for column in X:
    if plotnum <=9:
        ax = plt.subplot(3,3, plotnum)
        sns.stripplot(x=y, y=X[column],hue=y)
    plotnum+=1
plt.show()

# %%
X= live.drop(columns=['Survived'])
y= live['Survived']

# %%
df_live= live.drop('Survived', axis=1)

# %%
scaler= StandardScaler()
X_scaled = scaler.fit_transform([['Pclass','Age''SibSp','Parch','Fare']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 2
#       1 scaler= StandardScaler()
# ----> 2 X_scaled = scaler.fit_transform([['SibSp','Parch','Fare']])
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:915, in TransformerMixin.fit_transform(self, X, y, **fit_params)
# ...

# %%
x_train, y_train, x_test, y_test= train_test_split(X_scaler,y,test_size=0.25, random_state=355)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 x_train, y_train, x_test, y_test= train_test_split(X_scaler,y,test_size=0.25, random_state=355)
#
# NameError: name 'X_scaler' is not defined
